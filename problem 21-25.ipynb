# %% [markdown]
# # Python Practice Book (Problem 21 - 25)

# %% [markdown]
# ### problem 21

# %%
ListA = [1,2,3]
sum(ListA)
# Out:
# 6

# %%
for i in ListA:
    print(i)
# Out:
# 1
# 2
# 3

# %%
def SumList(x):
    s = x[0]
    n = len(x)
    for e in range(1,n):
        s += x[e]
    return(s)

SumList([1,2,3])
# Out:
# 6

# %% [markdown]
# ### problem 22

# %%
sum(["Hello","World"])
sum(["aa","bb","cc"])

#Error เพราะ sum ใช้กับ str ไม่ได้
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-cac22da942f0> in <module>
# ----> 1 sum(["Hello","World"])
#       2 sum(["aa","bb","cc"])
#       3
#       4 #Error เพราะ sum ใช้กับ str ไม่ได้
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
def sum(x):
    s = x[0]
    n = len(x)
    for e in range(1,n):
        s += x[e]
    return(s)

sum(["Hello","World"])
# Out:
# 'HelloWorld'

# %% [markdown]
# ### problem 23

# %%
#product([1,2,3]) >>> 6
def product(x):
    s = x[0]
    n = len(x)
    for e in range(1,n):
        s *= x[e]
    return(s)

product([1,2,3])
# Out:
# 6

# %% [markdown]
# ### problem 24

# %%
def factorial(x):
    list = []
    for e in range(1,x+1):
        list.append(e)
    return(product(list))

factorial(4)
# Out:
# 24

# %% [markdown]
# ### problem 25

# %%
def reverse(x):
    list = []
    n = len(x)
    s = x[0]
    for e in range(1,n+1):
        list.append(x[-e])
        
    return(list)

print (reverse([1,2,3,4]))
print (reverse(reverse([1,2,3,4])))
# Out:
# [4, 3, 2, 1]
# [1, 2, 3, 4]
